# %% [markdown]
# #Analisis Faktor-Faktor yang Mempengaruhi Efesiensi Energi Kendaraan Listrik
#
# ##Nama : Akhmad Rafliansyah
# ##NIM : 2509116045
# ##Kelas : B

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/EV Energy Efficiency Dataset.csv'

# %%
df = pd.read_csv(path)
df
# Out:
#       Model year        Make                            Model  \
# 0           2012  Mitsubishi                           i-MiEV
# 1           2012      Nissan                             LEAF
# 2           2013        Ford                   Focus Electric
# 3           2013  Mitsubishi                           i-MiEV
# 4           2013      Nissan                             LEAF
# ...          ...         ...                              ...
# 1192        2026       Volvo            EX30 Twin Performance
# 1193        2026       Volvo  EX30 Cross Country (18" Wheels)
# 1194        2026       Volvo  EX30 Cross Country (19" Wheels)
# 1195        2026       Volvo                             EX40
# 1196        2026       Volvo                        EX40 Twin
#
#                      Vehicle class  Motor (kW)  Recharge time (h)  \
# 0                       Subcompact          49                7.0
# 1                         Mid-size          80                7.0
# 2                          Compact         107                4.0
# 3                       Subcompact          49                7.0
# 4                         Mid-size          80                7.0
# ...                            ...         ...                ...
# 1192  Sport utility vehicle: Small         315                8.0
# 1193  Sport utility vehicle: Small         315                8.0
# 1194  Sport utility vehicle: Small         315                8.0
# 1195  Sport utility vehicle: Small         185                8.0
# 1196  Sport utility vehicle: Small         300                8.0
#
#       Energy Efficiency (km/kWh)
# 0                       5.347594
# 1                       4.739336
# 2                       5.000000
# 3                       5.347594
# 4                       4.739336
# ...                          ...
# 1192                    5.181347
# 1193                    4.255319
# 1194                    4.716981
# 1195                    5.076142
# 1196                    4.464286
#
# [1197 rows x 7 columns]

# %% [markdown]
# ## Business Understanding
#
# ### Business objective
# Business objective dari analisis ini adalah untuk Mengidentifikasi faktor apa saja yang mempengaruhi efisiensi dari energi kendaraan listrik agar dapat dikembangkan dan dievaluasi kedepannya, menganalisis hubungan antara spesifikasi kendaraan listrik terhadap dengan tingkat efesiensi energinya, serta mengkaji bagaimana tren perkembangan efesiensi energi kendaraan listrik dari tahun 2012-2026 guna memperoleh insight yang dapat digunakan sebagai dasar pengambilan keputusan dan pengembangan teknologi yang lebih efisien.
#
# ### Assess Situation
# Dataset yang digunakan dalam analisis ini adalah kumpulan data spesifikasi komprehensif untuk 1.197 kendaraan listrik dari tahun 2012 hingga 2026. dataset ini berisi 7 kolom atau variabel utama. 3 kolom merupakan fitur kategorikal yaitu merek, model, dan kelas kendaraan. lalu 4 kolom lainnya yaitu fitur numerik yaitu tahun model, daya motor, waktu pengisian, dan efisiensi energi. Selain itu data juga menunjukan efesiensi energi yang berkisar sebesar 2,11 hingga 6,94 km/kwh dan satu merek mobil yang paling mendominasi efisiensi energinya yaitu tesla yang berkisar sebesar 28,2% dari total data. Tantangan yang mungkin akan muncul adalah ketidakseimbangan data antara merek mobil dan kelas kendaraannya, serta kemungkinan adanya outlier pada variabel daya kendaraan dan waktu pengisian daya. oleh karena itu, sebelum menganalisis dan memvisualisasi data, data harus di proses di bagian data preparation.
#
# ### Analytic goals
# 1. Mengidentifikasi variabel yang berpotensi mempengaruhi efisensi energi kendaraan listrik melalui analisis deskriptif.
# 2. Melakukan analisis korelasi antara spesifikasi teknis seperti tenaga kendaraan dan waktu pengisian dayanya dengan tingkat efisensi energi kendaraan listrik.
# 3. Membuat visualisasi data seperti line chart, bar chart atau scatter plot dari tren perkembangan efisiensi energi kendaraan listrik  dari tahun 2012-2026.
#
# ### Project plan
# 1. Mengumpulkan dan memahami dataset kendaraan litrik yang diperoleh dari kaggle.
# 2. Melakukan cleaning data atau pembersihan data seperti mencari missing value dan duplikasi.
# 3. Memilih variabel data yang relevan dengan tingkat efisiensi energi kendaraan listrik.
# 4. Melakukan analisis deskriptif untuk memahami kondisi dan karakteristrik datanya serta analisis korelasi untuk mengetahui hubungan antar variabel numerik.
# 5. Membuat Visualisasi data seperti line chart, bar chart, dan scatter plot untuk menampilkan tren perkembangan efisiensi energi kendaraan listrik dari tahun 2012-2026 serta melihat pola hubungan antar variabelnya.
# 6. Menjelaskan hasil analisis yang telah didapat, menyusun dan menarik kesimpulan, kamudian memberikan insight berdasarkan analisis yang telah dilakukan guna sebagai pendukung dalam pengambilan keputusan terhadap pengembangan energi kendaraan listrik yang efisien.

# %% [markdown]
# #Struktur Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Model year                  1197 non-null   int64
#  1   Make                        1197 non-null   object
#  2   Model                       1197 non-null   object
#  3   Vehicle class               1197 non-null   object
#  4   Motor (kW)                  1197 non-null   int64
#  5   Recharge time (h)           1197 non-null   float64
#  6   Energy Efficiency (km/kWh)  1197 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 65.6+ KB

# %% [markdown]
# 1. Model Year: jumlah baris: 1197 Tipe Data: int64 Deskripsi: Tahun Model
# 2. Make: jumlah baris: 1197 Tipe Data: object Deskripsi: Merek
# 3. Model: jumlah baris: 1197 Tipe Data: object Deskripsi: Model
# 4. Vehicle class: jumlah baris: 1197 Tipe Data: object Deskripsi: Kelas Kendaraan
# 5. Motor (KW): jumlah baris: 1197 Tipe Data: int64 Deskripsi: daya motor listrik mobil
# 6. Recharge time (h): jumlah baris: 1197 Tipe Data: float64 Deskripsi: Waktu Pengisian
# 7. Energy Efficiency (km/kwh): jumlah baris: 1197 Tipe Data: float64 Deskripsi: efiensi energi

# %% [markdown]
# #Statistik Deskriptif

# %%
df.describe(include='all')
# Out:
#          Model year   Make    Model                    Vehicle class  \
# count   1197.000000   1197     1197                             1197
# unique          NaN     37      590                               12
# top             NaN  Tesla  Niro EV  Sport utility vehicle: Standard
# freq            NaN    176        8                              311
# mean    2023.231412    NaN      NaN                              NaN
# std        2.881857    NaN      NaN                              NaN
# min     2012.000000    NaN      NaN                              NaN
# 25%     2022.000000    NaN      NaN                              NaN
# 50%     2024.000000    NaN      NaN                              NaN
# 75%     2025.000000    NaN      NaN                              NaN
# max     2026.000000    NaN      NaN                              NaN
#
#          Motor (kW)  Recharge time (h)  Energy Efficiency (km/kWh)
# count   1197.000000        1197.000000                 1197.000000
# unique          NaN                NaN                         NaN
# top             NaN                NaN                         NaN
# freq            NaN                NaN                         NaN
# mean     341.289891          10.547285                    4.453765
# std      152.722951           2.706302                    0.856691
# min       35.000000           3.000000                    2.114165
# 25%      230.000000           8.500000                    3.787879
# 50%      335.000000          10.500000                    4.366812
# 75%      420.000000          12.000000                    5.102041
# max      930.000000          18.600000                    6.944444

# %% [markdown]
# 1. Count (Kelengkapan Data)
# Berdasarkan data, total baris data adalah 1197. Disemua kolom, semua datanya adalah 1197. Artinya semua kolom data memiliki data yang lengkap yaitu 1197 data.
#
#
#
# ---
#
#
#
# 2. Mean vs Median (Distribusi Data)
#
# * Kolom Motor (kW)
#   * Mean = 341.28
#   * Median = 335
#
#   Nilai mean sangat dekat dengan nilai median yang artinya distribusi daya kendaraan relatif simetris. Juga, Tidak ada outlier ekstrem yang mendominasi.
#
# * Kolom Recharge time (h)
#   * Mean = 10.54
#   * Median = 10.50
#  Nilai mean dan median hampir sama yang artinya waktu pengisian daya cederung normal dan stabil tanpa penyimpangan yang esktrem.
#
# * Kolom Eneregy Efficiency (km/kWh)
#   * Mean = 4.45
#   * Median = 4.36 -
#   Nilai mean sedikit lebih besar dari median yang artinya terdapat beberapa kendaraan dengan efisiensi energi tinggi yang membuat nilai rata rata naik
#
# Kesimpulan: secara umum variabel numerik memberikan distribusi yang cukup seimbang. namun ada satu variabel yang sedikit skewness yaitu Energy Efficiency
#
#
# ---
#
#
#
# 3. Min dan Max (Validasi Logika)
#
# * Motor (kW)
#   * Min = 35
#   * Max = 930
#
# * Recharge time (h)
#   * Min = 3
#   * Max = 18.6
#
# * Energy Efficiency (km/kWh)
#   * Min = 2.11
#   * Max = 6.94
#
# Kesimpulan:
# * Nilai Motor (kW) rentangnya lebar tapi tetap logis. Artinya mencerminkan variasi kendaraan dari EV kecil hingga performa tinggi.
#
# * Nilai Recharge time (h) rentangnya masih masuk akal. Artinya terdepat perbedaan teknologi charging dan kapasitas baterai.
#
# * Nilai Energy Efficiency (km/kWh) variasinya wajar menunjukkan adanya perbedaan efisiensi energi antar model kendaraan.
#
#
#
# ---
#
#
#
# 4. Standar Deviasi (std) - Variabilitas Data
#
# * Motor (kW)
#   * Mean = 341.28
#   * Std = 152.72
#
# * Recharge time (h)
#   * Mean = 10.54
#   * Std = 2.70
#
# * Energy Efficiency (km/kWh)
#   * Mean = 4.45
#   * Std = 0.85
#
# Kesimpulan:
#
# * Pada kolom Motor (kW) Std tergolong sangat besar dar
# * Pada kolom Profit, nilai standar deviasi yang jauh lebih besar (676,75) daripada rata-ratanya (417,48) mengindikasikan bahwa tingkat keuntungan antar transaksi sangat tidak stabil/bervariasi, mulai dari kerugian besar hingga keuntungan yang sangat tinggi.

# %% [markdown]
# #Date Type check

# %%
df.dtypes
# Out:
# Model year                      int64
# Make                           object
# Model                          object
# Vehicle class                  object
# Motor (kW)                      int64
# Recharge time (h)             float64
# Energy Efficiency (km/kWh)    float64
# dtype: object

# %% [markdown]
# ###Insight/penjelasan output
# 1. kolom numerik: pada kolom data ini model year dan motor (kw) bertipe int64 karena semua nilai datanya berupa bilangan bulat. sedangkan Recharge time (h) dan Energy Efficiency (km/kwh) bertipe float64 karena semua nilai datanya merupakan bilangan desimal. Artinya tipe data numerik ini sudah sesuai dengan karakteristik datanya.
# 2. kolom kategorikal: pada kolom data ini make, model, vehicle class bertipe object karena berisi data teks/kategorikal. Tipe data ini sudah sesuai dengan kolom tersebut yang berisi informasi teks/kategori.

# %% [markdown]
# #Inconsistent values

# %% [markdown]
# 1. Model Year

# %%
print(df['Model year'].unique())
# Out:
# [2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025
#  2026]

# %% [markdown]
# ######Pada kolom Model year tidak ada inconsistent values semua ditulis dengan konsisten

# %% [markdown]
# 2. Make

# %%
print(df['Make'].unique())
# Out:
# ['Mitsubishi' 'Nissan' 'Ford' 'smart' 'Tesla' 'Chevrolet' 'BMW' 'Kia'
#  'Tesla ' 'Hyundai' 'Volkswagen' 'Audi' 'Jaguar' 'smart EQ' 'MINI'
#  'Porsche' 'Polestar' 'Volvo' 'Lucid' 'Mazda' 'Mercedes-Benz' 'Rivian'
#  'Cadillac' 'Fisker' 'Genesis' 'Lexus' 'Subaru' 'Toyota' 'VinFast' 'Acura'
#  'Dodge' 'FIAT' 'GMC' 'Honda' 'Jeep' 'Rolls-Royce' 'Ford ']

# %% [markdown]
# #####Pada kolom Make ada inconsistent values yaitu Tesla dan Ford, inconsistennya yaitu sebagian penulisan Tesla dan Ford itu berbeda yaitu berupa spasi tambahan sebelum tanda petik kedua

# %% [markdown]
# 3. Model

# %%
print(df['Model'].unique())
# Out:
# ['i-MiEV' 'LEAF' 'Focus Electric' 'fortwo electric drive cabriolet'
#  'fortwo electric drive coupe' 'Model S (40 kWh)' 'Model S (60 kWh)'
#  'Model S (85 kWh)' 'Model S Performance' 'Spark EV' 'i3' 'Soul EV'
#  'Model S (70 kWh)' 'Model S (85/90 kWh)' 'Model S 70D' 'Model S 85D/90D'
#  'Model S P85D/P90D' 'LEAF (24 kWh)' 'LEAF (30 kWh)'
#  'Model S (60 kWh pre-6/16)' 'Model S (75 kWh)' 'Model S 60D'
#  'Model S 75D' 'Model S 90D (Refresh)' 'Model S P90D (Refresh)'
#  'Model S P100D' 'Model X 60D' 'Model X 75D' 'Model X 90D' 'Model X P90D'
#  'Model X P100D' 'i3 (60 Ah)' 'i3 (94 Ah)' 'Bolt EV' 'IONIQ Electric'
#  'Model S 90D' 'Model S 100D' 'Model S P90D' 'Model X 100D' 'e-Golf' 'i3s'
#  'Model 3 Mid Range' 'Model 3 Long Range' 'Model 3 Long Range AWD'
#  'Model 3 Long Range AWD Performance' 'e-tron 55 quattro' 'i3 (120 Ah)'
#  'i3s (120 Ah)' 'Kona Electric' 'I-PACE' 'Niro EV' 'LEAF (40 kWh)'
#  'LEAF S PLUS' 'LEAF SV/SL PLUS' 'fortwo cabriolet' 'fortwo coupe'
#  'Model 3 Standard Range' 'Model 3 Standard Range Plus'
#  'Model S Standard Range' 'Model S Long Range'
#  'Model S Performance (19" Wheels)' 'Model S Performance (21" Wheels)'
#  'Model X Standard Range' 'Model X Long Range'
#  'Model X Performance (20" Wheels)' 'Model X Performance (22" Wheels)'
#  'e-tron Sportback 55 quattro' 'Soul EV (120 Ah)' 'Soul EV (180 Ah)'
#  'Cooper SE 3 Door' 'Taycan 4S (Performance Battery Plus)' 'Taycan Turbo'
#  'Taycan Turbo S' 'Model 3 Long Range AWD Performance (18" Wheels)'
#  'Model 3 Long Range AWD Performance (19" Wheels)'
#  'Model 3 Long Range AWD Performance (20" Wheels)'
#  'Model S Long Range Plus (pre-15/6/20)' 'Model S Long Range Plus'
#  'Model X Long Range Plus' 'Model Y Long Range AWD' 'Model Y Performance'
#  'Model Y Performance (21" Wheels)' 'Mustang Mach-E Standard Range'
#  'Mustang Mach-E Standard Range AWD'
#  'Mustang Mach-E Extended Range (19" Wheels)'
#  'Mustang Mach-E Extended Range AWD' 'Mustang Mach-E California Route 1'
#  'Mustang Mach-E GT Performance Edition' '2' 'Taycan 4 Cross Turismo'
#  'Taycan 4S (Performance Battery)' 'Taycan 4S Cross Turismo'
#  'Taycan Turbo Cross Turismo' 'Taycan Turbo S Cross Turismo'
#  'Model 3 Performance' 'Model S Plaid (19" Wheels)'
#  'Model S Plaid (21" Wheels)' 'Model Y Standard Range' 'ID.4 Pro'
#  'ID.4 AWD Pro' 'XC40 Recharge' 'e-tron S Sportback quattro (20" Wheels)'
#  'e-tron S Sportback quattro (21" or 22" Wheels)' 'e-tron GT'
#  'RS e-tron GT' 'Q4 50 e-tron quattro' 'Q4 50 e-tron Sportback quattro'
#  'i4 eDrive40 (18" Wheels)' 'i4 eDrive40 (19" Wheels)'
#  'i4 M50 xDrive (19" Wheels)' 'i4 M50 xDrive (20" Wheels)'
#  'iX xDrive50 (20" Wheels)' 'iX xDrive50 (21" Wheels)'
#  'iX xDrive50 (22" Wheels)' 'Bolt EUV' 'F-150 Lightning Standard Range'
#  'F-150 Lightning Extended Range' 'F-150 Lightning Platinum'
#  'Mustang Mach-E Extended Range' 'Mustang Mach-E California Route 1 AWD'
#  'IONIQ 5 Standard Range' 'IONIQ 5 Long Range' 'IONIQ 5 Long Range AWD'
#  'EV6 Standard Range' 'EV6 Long Range' 'EV6 Long Range AWD'
#  'Air Dream P AWD (19" Wheels)' 'Air Dream P AWD (21" Wheels)'
#  'Air Dream R AWD (19" Wheels)' 'Air Dream R AWD (21" Wheels)'
#  'Air Grand Touring AWD (19" Wheels)' 'Air Grand Touring AWD (21" Wheels)'
#  'MX-30' 'EQB 350 4MATIC SUV' 'EQS 580 4MATIC Sedan' '2 Single Motor'
#  '2 Dual Motor' 'Taycan GTS' 'Taycan GTS Sport Turismo' 'R1S' 'R1T'
#  'Model 3 RWD' 'Model S' 'Model X' 'Model X Plaid (20" Wheels)'
#  'Model X Plaid (22" Wheels)' 'Model Y AWD' 'C40 Recharge Twin'
#  'XC40 Recharge Twin' 'Q4 Sportback 50 e-tron quattro'
#  'i4 eDrive35 Gran Coupe (18" Wheels)'
#  'i4 eDrive35 Gran Coupe (19" Wheels)'
#  'i4 eDrive40 Gran Coupe (18" Wheels)'
#  'i4 eDrive40 Gran Coupe (19" Wheels)' 'i4 M50 Gran Coupe (19" Wheels)'
#  'i4 M50 Gran Coupe (20" Wheels)' 'i7 xDrive60 (19" Wheels)'
#  'i7 xDrive60 (20" Wheels)' 'i7 xDrive60 (21" Wheels)'
#  'iX xDrive40 (20" Wheels) ' 'iX xDrive40 (21" Wheels) '
#  'iX xDrive40 (22" Wheels) ' 'iX M60 (21" Wheels)' 'iX M60 (22" Wheels)'
#  'LYRIQ' 'LYRIQ AWD' 'Ocean Extreme/One' 'Ocean Ultra'
#  'Mustang Mach-E Standard Range (LFP)'
#  'Mustang Mach-E Standard Range AWD (LFP)' 'Electrified G80'
#  'GV60 Advanced AWD' 'GV60 Performance AWD' 'Electrified GV70'
#  'IONIQ 6 Standard Range' "IONIQ 6 Long Range (18'' Wheels)"
#  "IONIQ 6 Long Range AWD (18'' Wheels)"
#  "IONIQ 6 Long Range AWD (20'' Wheels)" 'EV6 Long Range AWD (19" Wheels)'
#  'EV6 Long Range AWD (20" Wheels)' 'EV6 GT AWD' 'RZ 450e AWD (18" Wheels)'
#  'RZ 450e AWD (20" Wheels)' 'Air Grand Touring XR (19" Wheels)'
#  'Air Grand Touring XR (20" Wheels)' 'Air Grand Touring XR (21" Wheels)'
#  'Air Grand Touring Performance (21" Wheels)' 'Air Pure (19" Wheels)'
#  'Air Pure (20" Wheels)' 'Air Touring (19" Wheels)'
#  'Air Touring (20" Wheels)' 'Air Touring (21" Wheels)'
#  'AMG EQE 4MATIC+ Sedan' 'AMG EQS 4MATIC+ Sedan' 'EQB 250+'
#  'EQE 350 4MATIC Sedan' 'EQE 350 4MATIC SUV' 'EQE 500 4MATIC Sedan'
#  'EQE 500 4MATIC SUV' 'EQS 450 4MATIC Sedan' 'EQS 450 4MATIC SUV'
#  'EQS 580 4MATIC SUV' '2 Dual Motor Performance Pack' '2 BST Edition'
#  'R1S (20" Wheels)' 'R1S (20" Wheels) All-Terrain'
#  'R1S (20" Wheels) AT Dual Large'
#  'R1S (20" Wheels) AT Performance Dual Large'
#  'R1S (20" Wheels) AT Dual Max' 'R1S (20" Wheels) AT Performance Dual Max'
#  'R1S (21" Wheels)' 'R1S (21" Wheels) Dual Large'
#  'R1S (21" Wheels) Performance Dual Large' 'R1S (21" Wheels) Dual Max'
#  'R1S (21" Wheels) Performance Dual Max' 'R1S (22" Wheels)'
#  'R1S (22" Wheels) Dual Large' 'R1S (22" Wheels) Performance Dual Large'
#  'R1S (22" Wheels) Dual Max' 'R1S (22" Wheels) Performance Dual Max'
#  'R1T (20" Wheels)' 'R1T (20" Wheels) All-Terrain'
#  'R1T (20" Wheels) AT Dual Large'
#  'R1T (20" Wheels) AT Performance Dual Large'
#  'R1T (20" Wheels) AT Dual Max' 'R1T (20" Wheels) AT Performance Dual Max'
#  'R1T (21" Wheels)' 'R1T (21" Wheels) Dual Large'
#  'R1T (21" Wheels) Performance Dual Large' 'R1T (21" Wheels) Dual Max'
#  'R1T (21" Wheels) Performance Dual Max' 'R1T (22" Wheels)'
#  'R1T (22" Wheels) Dual Large' 'R1T (22" Wheels) Performance Dual Large'
#  'R1T (22" Wheels) Dual Max' 'R1T (22" Wheels) Performance Dual Max'
#  'Solterra AWD' 'Model 3 Long Range AWD (pre-1/10/23)'
#  'Model 3 Long Range AWD (Import)' 'Model Y RWD'
#  'Model Y Long Range AWD (Import)' 'Model Y Performance (Import)' 'bZ4X'
#  'bZ4X AWD' 'VF8 ECO' 'VF8 PLUS' 'VF8 PLUS Performance' 'ID.4'
#  'ZDX A-SPEC AWD' 'ZDX Type S AWD' 'Q4 45 e-tron' 'Q4 50 e-tron'
#  'Q4 Sportback 50 e-tron' 'Q4 55 e-tron' 'Q4 Sportback 55 e-tron'
#  'Q8 e-tron' 'Q8 Sportback e-tron' 'SQ8 e-tron (20" Wheels)'
#  'SQ8 e-tron (21" or 22" Wheels)' 'SQ8 Sportback e-tron (20" Wheels)'
#  'SQ8 Sportback e-tron (21" or 22" Wheels)'
#  'i4 xDrive40 Gran Coupe (18" Wheels)'
#  'i4 xDrive40 Gran Coupe (19" Wheels)' 'i5 M60 Sedan (19" Wheels)'
#  'i5 M60 Sedan (20" Wheels)' 'i5 M60 Sedan (21" Wheels)'
#  'i7 xDrive60 Sedan (19" Wheels)' 'i7 xDrive60 Sedan (20" Wheels)'
#  'i7 xDrive60 Sedan (21" Wheels)' 'i7 M70 xDrive Sedan (20" Wheels)'
#  'i7 M70 xDrive Sedan (21" Wheels)' 'iX xDrive50 (20" Wheels) '
#  'iX xDrive50 (22" Wheels) ' 'LYRIQ (11.5 kW Charger)'
#  'LYRIQ (19.2 kW Charger)' 'LYRIQ AWD (11.5 kW Charger)'
#  'LYRIQ AWD (19.2 kW Charger)' 'Blazer EV RS' 'Blazer EV 2LT/RS AWD'
#  'Equinox EV' 'Equinox EV AWD' 'Silverado EV 3WT' 'Silverado EV 4WT'
#  'Charger Daytona R/T AWD 2Dr (18" Nexen Tire)'
#  'Charger Daytona R/T AWD 2Dr (20" Nexen Tire)'
#  'Charger Daytona R/T AWD 2Dr (20" Goodyear Tire)'
#  'Charger Daytona Scat Pack Trk Pack AWD 2Dr AS Tire'
#  'Charger Daytona Scat Pack Trk Pack AWD 2Dr 3S Tire' '500e'
#  'Ocean Extreme (20" Wheels)' 'Ocean Extreme (22" Wheels)'
#  'Ocean Sport (20" Wheels)' 'Ocean Sport (22" Wheels)'
#  'Ocean Ultra (20" Wheels)' 'Ocean Ultra (22" Wheels)'
#  'F-150 Lightning Pro' 'Mustang Mach-E GT' 'Mustang Mach-E Rally'
#  'HUMMER EV2X Pickup' 'HUMMER EV2X Pickup Mud Terrain Tire'
#  'HUMMER EV2X SUV' 'HUMMER EV2X SUV Mud Terrain Tire' 'HUMMER EV3X SUV'
#  'HUMMER EV3X SUV Mud Terrain Tire' 'Prologue EX AWD' 'Prologue EX-L AWD'
#  'Prologue Touring AWD' "IONIQ 6 Long Range (20'' Wheels)"
#  'Kona Electric Long Range' 'Wagoneer S AWD (Falken Tire)'
#  'Wagoneer S AWD (Pirelli Tire)' 'EV6 Wind' 'EV6 Land AWD (19" Wheels)'
#  'EV6 Land AWD (20" Wheels)' 'EV9 Light' 'EV9 Wind' 'EV9 Land AWD'
#  'EV9 Land AWD GT-Line' 'Air Grand Touring XR AWD (19" Wheels)'
#  'Air Grand Touring XR AWD (20" Wheels)'
#  'Air Grand Touring XR AWD (21" Wheels)' 'Air Sapphire AWD'
#  'Air Touring AWD (19" Wheels)' 'Air Touring AWD (20" Wheels)'
#  'Air Touring AWD (21" Wheels)' 'AMG EQE 4MATIC+ SUV' 'EQB 300 4MATIC'
#  'Maybach EQS 680 4MATIC SUV' 'ARIYA Engage' 'ARIYA Evolve+'
#  'ARIYA Evolve e-4ORCE' 'ARIYA Evolve+ e-4ORCE' 'ARIYA Platinum+ e-4ORCE'
#  'LEAF SV' 'LEAF SV PLUS' '2 Single Motor (19" Wheels)'
#  '2 Single Motor (20" Wheels)' '2 Dual Motor (19" Wheels)'
#  '2 Dual Motor (20" Wheels)' 'Macan 4 Electric' 'Macan Turbo Electric'
#  'R1S All-Terrain Dual Large (20" Wheels)'
#  'R1S AT Performance Dual Large (20" Wheels)'
#  'R1S Dual Large (21" Wheels)' 'R1S Performance Dual Large (21" Wheels)'
#  'R1S Dual Large (22" Wheels)' 'R1S Performance Dual Large (22" Wheels)'
#  'R1S All-Terrain Dual Max (20" Wheels)'
#  'R1S All-Terrain Performance Dual Max (20" Wheels)'
#  'R1S Dual Max (21" Wheels)' 'R1S Performance Dual Max (21" Wheels)'
#  'R1S Dual Max (22" Wheels)' 'R1S Performance Dual Max (22" Wheels)'
#  'R1S Quad Large (20" Wheels)' 'R1S All-Terrain Quad Large (20" Wheels)'
#  'R1S Quad Large (21" Wheels)' 'R1S Quad Large (22" Wheels)'
#  'R1T All-Terrain Dual Large (20" Wheels)'
#  'R1T AT Performance Dual Large (20" Wheels)'
#  'R1T Dual Large (21" Wheels)' 'R1T Performance Dual Large (21" Wheels)'
#  'R1T Dual Large (22" Wheels)' 'R1T Performance Dual Large (22" Wheels)'
#  'R1T All-Terrain Dual Max (20" Wheels)'
#  'R1T All-Terrain Performance Dual Max (20" Wheels)'
#  'R1T Dual Max (21" Wheels)' 'R1T Performance Dual Max (21" Wheels)'
#  'R1T Dual Max (22" Wheels)' 'R1T Performance Dual Max (22" Wheels)'
#  'R1T Quad Large (20" Wheels)' 'R1T All-Terrain Quad Large (20" Wheels)'
#  'R1T Quad Large (21" Wheels)' 'R1T Quad Large (22" Wheels)'
#  'Spectre (22" Wheels)' 'Spectre (23" Wheels)'
#  'Black Badge Spectre (22" Wheels)' 'Black Badge Spectre (23" Wheels)'
#  'Model 3 RWD (Import)' 'Model Y RWD (Import)' 'VF9 ECO' 'VF9 PLUS'
#  'ID.4 S' 'ID.4 Pro S' 'ID.4 AWD Pro S' 'C40 Recharge' 'A6 60 e-tron'
#  'A6 60 e-tron ultra' 'Q4 55 e-tron quattro'
#  'Q4 Sportback 55 e-tron quattro' 'Q6 60 e-tron quattro (19" Wheels)'
#  'Q6 60 e-tron quattro (20" Wheels)'
#  'Q6 Sportback 60 e-tron quattro (19" Wheels)'
#  'Q6 Sportback 60 e-tron quattro (20" Wheels)' 'Q8 e-tron (20" Wheels)'
#  'Q8 e-tron (21" Wheels)' 'Q8 Sportback e-tron (20" Wheels)'
#  'Q8 Sportback e-tron (21" Wheels)' 'RS e-tron GT quattro performance'
#  'S e-tron GT (20" Wheels)' 'S e-tron GT (21" Wheels)'
#  'S6 e-tron quattro (20" Wheels)' 'S6 e-tron quattro (21" Wheels)'
#  'SQ6 e-tron' 'SQ6 Sportback e-tron quattro'
#  'i4 M50 xDrive Gran Coupe (19" Wheels)'
#  'i4 M50 xDrive Gran Coupe (20" Wheels)' 'i5 xDrive40 Sedan (19" Wheels)'
#  'i5 xDrive40 Sedan (20" Wheels)' 'i5 xDrive40 Sedan (21" Wheels)'
#  'i5 M60 xDrive Sedan (19" Wheels)' 'i5 M60 xDrive Sedan (20" Wheels)'
#  'i5 M60 xDrive Sedan (21" Wheels)' 'iX xDrive40 (20" Wheels)'
#  'iX xDrive40 (21" Wheels)' 'iX xDrive40 (22" Wheels)' 'CELESTIQ'
#  'OPTIQ (11.5 kW Charger)' 'OPTIQ (19.2 kW Charger)' 'Blazer EV'
#  'Blazer EV (22" Wheels)' 'Blazer EV RWD' 'Blazer EV LT/RS AWD'
#  'Blazer EV SS AWD' 'Equinox EV AWD (11.5 kW Charger)'
#  'Equinox EV AWD (19.2 kW Charger)'
#  'Silverado EV LT Ext Range (11.5 kW Charger)'
#  'Silverado EV LT/RST Ext Range (19.2 kW Charger)'
#  'Silverado EV WT Std Range' 'Silverado EV WT Ext Range (11.5 kW Charger)'
#  'Silverado EV WT Ext Range (19.2 kW Charger)'
#  'Silverado EV WT Max Range (19.2 kW Charger)'
#  'F-150 Lightning Extended Range (123 kWh)'
#  'F-150 Lightning Extended Range (131 kWh)'
#  'F-150 Lightning PRO Extended Range (131 kWh)'
#  'HUMMER EV3X Pickup (20M Battery)'
#  'HUMMER EV3X Pickup Mud Terrain Tire (20M Battery)'
#  'Sierra EV Extended Range' 'IONIQ 5 Long Range AWD (19" Wheels)'
#  'IONIQ 5 Long Range AWD (20" Wheels)' 'IONIQ 5 Long Range AWD XRT'
#  'IONIQ 5 N' 'Kona Electric (17" Wheels)' 'Kona Electric (19" Wheels)'
#  'EV6 Light' 'Air Grand Touring XR AWD (20" Wheels) '
#  'Air Grand Touring XR AWD (21" Wheels) ' 'G 580 with EQ Technology'
#  'Countryman SE ALL4 (18" Wheels)' 'Countryman SE ALL4 (19" Wheels)'
#  'ARIYA Platinum+ e-4ORCE (19" Wheels)'
#  'ARIYA Platinum+ e-4ORCE (20" Wheels)'
#  '3 Long Range Single Motor (20" Wheels)'
#  '3 Long Range Single Motor (21" Wheels)'
#  '3 Long Range Single Motor (22" Wheels)'
#  '3 Long Range Dual Motor (20" Wheels)'
#  '3 Long Range Dual Motor (21" Wheels)'
#  '3 Long Range Dual Motor (22" Wheels)'
#  '3 Long Range Dual Motor Performance Pack' '4 Long Range Single Motor'
#  '4 Long Range Dual Motor' 'Macan Electric' 'Macan 4S Electric'
#  'Taycan Turbo GT' 'Taycan Turbo GT with Weissach Package'
#  'R1S Dual Standard (20" Wheels)' 'R1S Dual Standard (22" Wheels)'
#  'R1S Dual Large (20" Wheels)' 'R1S Performance Dual Large (20" Wheels)'
#  'R1S Dual Large Plus (20" Wheels)' 'R1S Dual Large Plus (22" Wheels)'
#  'R1S All-Terrain Dual Large Plus (20" Wheels)'
#  'R1S AT Performance Dual Large Plus (20" Wheels)'
#  'R1S Performance Dual Large Plus (20" Wheels)'
#  'R1S Performance Dual Large Plus (22" Wheels)'
#  'R1S Dual Max (20" Wheels)' 'R1S Performance Dual Max (20" Wheels)'
#  'R1S Tri Max (22" Wheels)' 'R1S All-Terrain Tri Max (20" Wheels)'
#  'R1T Dual Standard (20" Wheels)' 'R1T Dual Standard (22" Wheels)'
#  'R1T Dual Large (20" Wheels)' 'R1T Performance Dual Large (20" Wheels)'
#  'R1T Dual Large Plus (20" Wheels)' 'R1T Dual Large Plus (22" Wheels)'
#  'R1T All-Terrain Dual Large Plus (20" Wheels)'
#  'R1T AT Performance Dual Large Plus (20" Wheels)'
#  'R1T Performance Dual Large Plus (20" Wheels)'
#  'R1T Performance Dual Large Plus (22" Wheels)'
#  'R1T Dual Max (20" Wheels)' 'R1T Performance Dual Max (20" Wheels)'
#  'R1T Tri Max (22" Wheels)' 'R1T All-Terrain Tri Max (20" Wheels)'
#  'Cybertruck AWD' 'Model 3 Long Range-I' 'Model 3 Long Range AWD-I'
#  'Model 3 Performance-I' 'Model Y Long Range-I'
#  'Model Y Long Range AWD-I ' 'Model Y Performance-I'
#  'bZ4X AWD (18" Wheels)' 'bZ4X AWD (20" Wheels)' 'VF7 PLUS' 'ID. Buzz Pro'
#  'ID. Buzz Pro 4MOTION' 'EC40' 'EC40 Twin'
#  'EX30 Single Motor Extended Range (18" Wheels)'
#  'EX30 Single Motor Ext Range (19" and 20" Wheels)'
#  'EX30 Twin Performance' 'EX40' 'EX40 Twin'
#  'EX90 Twin Motor (20" and 22" Wheels)' 'EX90 Twin Motor (21" Wheels)'
#  'EX90 Twin Motor Performance (20" and 22" Wheels)'
#  'EX90 Twin Motor Performance (21" Wheels)'
#  'i4 M60 xDrive Gran Coupe (19" Wheels)'
#  'i4 M60 xDrive Gran Coupe (20" Wheels)' 'iX xDrive45 (20" Wheels)'
#  'iX xDrive45 (21" Wheels)' 'iX xDrive45 (22" Wheels)'
#  'iX xDrive45 (23" Wheels)' 'iX xDrive60 (20" Wheels)'
#  'iX xDrive60 (21" Wheels)' 'iX xDrive60 (22" Wheels)'
#  'iX xDrive60 (23" Wheels)' 'iX M70 (21" Wheels)' 'iX M70 (22" Wheels)'
#  'iX M70 (23" Wheels)' 'LYRIQ-V (11.5 kW Charger)'
#  'LYRIQ-V (19.2 kW Charger)' 'OPTIQ AWD (11.5 kW Charger)'
#  'OPTIQ AWD (19.2 kW Charger)' 'OPTIQ-V (11.5 kW Charger)'
#  'OPTIQ-V (19.2 kW Charger)' 'VISTIQ (11.5 kW Charger)'
#  'VISTIQ (19.2 kW Charger)' 'Silverado EV LT Std Range'
#  'Silverado EV LT Ext Range (19.2 kW Charger)'
#  'Silverado EV Trail Boss Ext Range (11.5 kW)' 'Silverado EV WT Ext Range'
#  'Silverado EV WT Max Range' 'Charger Daytona R/T AWD 245/55ZR18'
#  'Charger Daytona R/T AWD 255/45R20' 'Charger Daytona R/T AWD 275/40R20'
#  'Charger Daytona R/T AWD 305/35ZR20'
#  'Charger Daytona Scat Pack AWD 305/35ZR20'
#  'Charger Daytona Scat Pack AWD 325/35ZR20 Rear'
#  'Charger Daytona Scat Pack AWD 325/35ZR20 Rear 3S' 'F-150 Lightning STX'
#  'Sierra EV Std Range' 'Sierra EV Denali Ext Range (11.5 kW Charger)'
#  'Sierra EV Denali Ext Range (19.2 kW Charger)'
#  'Sierra EV Elevation Ext Range (11.5 kW Charger)'
#  'Sierra EV Elevation Ext Range (19.2 kW Charger)' 'IONIQ 9' 'IONIQ 9 AWD'
#  'IONIQ 9 AWD Performance' 'EV9 GT' 'RZ 350e' 'RZ 550e AWD'
#  'CLA 350 4MATIC with EQ Technology' 'EQE 320 4MATIC Sedan'
#  'EQE 320 4MATIC SUV' 'EQS 400 4MATIC SUV' 'EQS 550 4MATIC SUV' 'ARIYA SV'
#  'ARIYA SL+' 'ARIYA SL e-4ORCE' 'ARIYA SL+ e-4ORCE' 'LEAF Platinum PLUS'
#  '4 Long Range Dual Motor Performance' 'R1S Quad Max (20" Wheels AT)'
#  'R1S Quad Max (22" Wheels)' 'R1S Quad Max (22" Wheels UHP)'
#  'R1T Quad Max (20" Wheels AT)' 'R1T Quad Max (22" Wheels)'
#  'R1T Quad Max (22" Wheels UHP)' 'Model X Plaid'
#  'Model Y Long Range AWD-B' 'Model Y Long Range AWD-B (pre-6/11/25)'
#  'Model Y Long Range AWD-I' 'bZ' 'bZ AWD' 'bZ Limited AWD' 'ID. Buzz'
#  'ID. Buzz 4MOTION' 'ID.4 AWD' 'EX30 Single Motor Extended Range'
#  'EX30 Cross Country (18" Wheels)' 'EX30 Cross Country (19" Wheels)']

# %% [markdown]
# #####Pada kolom Model tidak ada inconsistent Values semua ditulis dengan konsisten

# %% [markdown]
# 4. Vehicle class

# %%
print(df['Vehicle class'].unique())
# Out:
# ['Subcompact' 'Mid-size' 'Compact' 'Two-seater' 'Full-size'
#  'Station wagon: Small' 'Sport utility vehicle: Standard'
#  'Sport utility vehicle: Small' 'Pickup truck: Standard' 'Minicompact'
#  'Station wagon: Mid-size' 'Minivan']

# %% [markdown]
# #####Pada kolom  Vehicle class tidak ada inconsistent values semua ditulis dengan konsisten

# %% [markdown]
# 5. Motor (kW)

# %%
print(df['Motor (kW)'].unique())
# Out:
# [ 49  80 107  35 225 270 310 104 125  81 285 280 515 386 568 150  88 100
#  135 110  60 202 335 358 300 294 160 211 398 580 360 460 198 216 258 320
#  191 293 321 494 750 312 220 370 390 475 250 400 318 420 168 239 829 696
#  611 215 385 170 380 650 192 291 210 240 397 254 373 350 232 272 234 111
#  430 230 783 462 484 140 265 418 496 276 314 260 375 295 442 485 255 247
#  180 381 500  87 414 207 197 242 428 600 149 282 330 930 142 178 290 470
#  203 266 185 315 435 377 606 478 432 200 340 445 520 570 634 449 296 491
#  690 221 337 550 425 440 345 226 374 165 235 245 764]

# %% [markdown]
# #####Pada kolom  Motor (kW) tidak ada inconsistent values semua ditulis dengan konsisten

# %% [markdown]
# 6. Recharge time (h)

# %%
print(df['Recharge time (h)'].unique())
# Out:
# [ 7.    4.    8.    6.   10.   12.    5.    9.3   5.5   5.3   3.    9.
#  13.    9.5  11.    3.7   8.5   5.8  10.5   8.8  10.9  10.7  11.4  10.1
#  15.   14.    7.5  11.8   8.1   6.3   8.7   8.4  11.25  6.5  18.   11.9
#   7.4  10.2   7.2   7.9   6.1   8.9   7.75  6.25  8.25 11.5  16.    6.7
#   9.4  12.7   6.2  14.6   7.1   9.9   7.7  15.2  14.5   7.25  6.75 12.75
#  15.5  11.2   5.9  18.6  13.3  13.7   7.8   9.6   8.2   6.9  10.75 10.25
#  13.6  11.7  13.8  12.1  10.8   8.85]

# %% [markdown]
# #####Pada kolom Recharge time (h) tidak ada inconsistent values semua ditulis dengan konsisten

# %% [markdown]
# 7. Energi Efficiency (km/kWh)

# %%
print(df['Energy Efficiency (km/kWh)'].unique())
# Out:
# [5.34759358 4.73933649 5.         5.10204082 4.5045045  4.56621005
#  4.23728814 5.61797753 5.43478261 5.95238095 5.02512563 4.83091787
#  4.76190476 4.44444444 5.37634409 4.69483568 4.95049505 4.92610837
#  4.52488688 4.65116279 4.42477876 4.40528634 4.25531915 4.09836066
#  5.68181818 6.4516129  4.85436893 4.54545455 4.16666667 5.74712644
#  5.29100529 5.18134715 5.31914894 5.84795322 6.21118012 5.55555556
#  4.06504065 3.53356891 5.4054054  3.63636364 5.12820513 6.41025641
#  6.32911392 5.20833333 4.62962963 4.58715596 4.29184549 3.7593985
#  3.66300366 5.15463917 3.30033003 3.31125828 3.22580645 6.7114094
#  5.52486188 5.58659218 5.78034682 3.7037037  4.31034483 3.90625
#  4.38596491 3.64963504 3.78787879 3.57142857 3.4965035  3.43642612
#  3.3444816  6.57894737 6.75675676 5.71428571 5.26315789 4.80769231
#  6.17283951 4.60829493 3.58422939 3.08641975 3.84615385 3.80228137
#  4.1322314  3.95256917 5.46448087 3.26797386 3.3557047  3.17460318
#  4.32900433 3.55871886 5.98802395 6.25       4.46428571 5.23560209
#  3.81679389 4.6728972  4.36681223 5.81395349 4.18410042 4.08163265
#  3.73134328 3.96825397 4.14937759 3.74531835 4.27350427 4.34782609
#  4.87804878 3.92156863 3.86100386 4.21940928 4.78468899 3.77358491
#  3.07692308 2.99401198 3.48432056 3.38983051 3.71747212 3.93700787
#  3.25732899 3.5971223  4.03225806 3.62318841 6.02409639 4.97512438
#  3.01204819 2.17864924 4.71698113 3.89105058 3.50877193 4.
#  4.20168067 3.87596899 3.18471338 5.05050505 2.47524752 2.24215247
#  2.43902439 2.53807107 2.40384615 3.83141762 6.53594771 6.36942675
#  4.01606426 5.4945055  5.07614213 3.54609929 6.49350649 3.27868853
#  3.98406374 3.33333333 2.84090909 4.48430493 3.67647059 4.048583
#  4.90196078 3.16455696 3.42465753 2.51889169 2.4691358  2.28832952
#  5.91715976 6.94444444 6.28930818 6.09756098 2.97619048 3.6900369
#  3.6101083  3.36700337 2.1141649  3.23624595 5.64971751 3.2051282
#  3.24675325 3.06748466 4.11522634 3.44827586 5.88235294 3.21543408
#  3.40136054]

# %% [markdown]
# #####Pada kolom Energy Efficiency (km/kWh) tidak ada inconsistent values semua ditulis dengan konsisten
#
# ---
#
# ####Kesimpulannya dari 7 kolom hanya 1 kolom yang ada inconsistent values yaitu kolom make berupa adanya sebagian data yang penulisannya berbeda. sedangkan kolom lainnya tidak ada inconsistent values semua ditulis dengan konsisten

# %% [markdown]
# #Missing Value

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                             Null Ratio in %
# Model year                              0.0
# Make                                    0.0
# Model                                   0.0
# Vehicle class                           0.0
# Motor (kW)                              0.0
# Recharge time (h)                       0.0
# Energy Efficiency (km/kWh)              0.0

# %% [markdown]
# #####Berdasarkan hasil pengecekkan data, null ratio tiap kolomnya 0% artinya tidak ada missing value pada dataset ini semua baris memiliki data yang lengkap

# %% [markdown]
# #Duplicate Value

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Model year, Make, Model, Vehicle class, Motor (kW), Recharge time (h), Energy Efficiency (km/kWh)]
# Index: []

# %% [markdown]
# ####Berdasarkan hasil pengecekkan data, di dataset ini terlihat tidak ada duplikasi, artinya setiap data pada dataset bersifat unik dan tidak perlu ditangani untuk penghapusan duplikat

# %% [markdown]
# #Outlier value

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                       Persentase Outliers
# Model year                             7.017544
# Motor (kW)                             2.422723
# Recharge time (h)                      1.336675
# Energy Efficiency (km/kWh)             0.000000

# %% [markdown]
# 1. Model year dengan persentase 7% menunjukkan adanya data dengan tahun jauh lebih tua atau lebih mudah dibandingkan dengan mayoritas data
# 2. Motor (kW) dengan persentase 2% outlier relatif kecil kemungkinan hanya ada beberapa daya motor listrik mobil yang sangat tinggi/rendah
# 3. Recharge time (h) dengan persentase 1% outlier sangat kecil artinya hanya sebagian kecil waktu pengisian daya yang tidak umum
# 4. Energy Efficiemcy (km/kWh) dengan persentase 0% artinya tidak ada data eksrem pada kolom ini, semua nilai datanya dalam batas yang normal

# %% [markdown]
# #Comparasion

# %% [markdown]
# Aktivitas: Membandingkan daya kendaraan (Motor (kw)) dengan tingkat efisiensi energi (Energy Efficiency (km/kWh)).
#
# Tujuan: Mengidentifikasi apakah tingkat daya kendaraan memengaruhi tingkat efisien energi.
#
# Visualisasi: scatterplot (diagram sebar)

# %%
Energy_Efficiency = df.groupby('Motor (kW)')['Energy Efficiency (km/kWh)'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.scatterplot(x=Energy_Efficiency.index, y=Energy_Efficiency.values, palette='viridis', hue=Energy_Efficiency.index, legend=False)
plt.title('total efisiensi energi berdasarkan daya ')
plt.xlabel('Motor (kW)')
plt.ylabel('Total efisiensi energi')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Titik data menyebar secara acak tidak membentuk garis naik atau turun yang jelas, artinya tidak ada hubungan linier yang kuat antara daya kendaraan dengan tingkat efisiensi energi dan bisa dikatakan besarnya daya kendaraan bukan faktor utama yang mempengaruhi efisiensi dari kendaraan.
#
# kesimpulannya kendaraan listrik dengan daya yang yang besar tidak selalu memiliki efisiensi energi yang tinggi.

# %% [markdown]
# #Composition

# %% [markdown]
# Aktivitas: Melihat proporsi atau persentase merek kendaraan berdasarkan tingkat efisiensi energinya.
#
# Tujuan: Mengetahui kategori merek kendaraan mana yang paling mendominasi dalam aspek efisiensi energi.
#
# Visualisasi: Pie Chart (Grafik Lingkaran).

# %%
Make_by_Energy_Efficiency = df.groupby('Make')['Energy Efficiency (km/kWh)'].sum().sort_values(ascending=False)
Make_by_Energy_Efficiency_top3 = Make_by_Energy_Efficiency.head(3)

plt.figure(figsize=(10, 8))
Make_by_Energy_Efficiency_top3.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Proporsi 3 merek kendaraan teratas berdasarkan tingkat efisiensi energi')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# Visualisasi composition menggunakan pie chart menunjukkan bahwa Tesla memiliki kontribusi efisiensi energi yang paling tinggi sebesar 45%, lalu disusul Rivian sebesar 29,1%, dan BMW sebesar 25,9%. Hal ini menunjukkan bahwa Tesla mendominasi dalam aspek efisiensi energi dibandingkan dua merek lainnya. selain itu Rivian dan BMW memiliki proporsi yang berdekatan, hal ini menunjukkan adanya tingkat efisiensi energy yang kompetitif diantara keduanya.

# %% [markdown]
# #Distribution

# %% [markdown]
# Aktivitas: Melakukan analisis distribusi nilai efisiensi energi kendaraan listrik dan bagaimana pola penyebaran datanya.
#
# Tujuan: mengidentifikasi apakah mayoritas kendaraan memiliki efisiensi energi yang rendah, sedang, atau tinggi, serta melihat pola distribusi apakah nilai normal, miring, atau ekstrem.
#
# Visualisasi: Histogram.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Energy Efficiency (km/kWh)'], bins=20, kde=True)
plt.title('Distribusi efisiensi kendaraan listrik')
plt.xlabel('Enegy Efficiency (km/kWh)')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Berdasarkan grafik, mayoritas kendaraan memiliki efisiensi energi pada rentang 3,5 hingga 5,0 km/kWh. Distribusi data menunjukkan pola yang mendekati normal, hal ini berarti penyebaran performa efisiensi energi relatif seimbang antar kendaraan. selain itu ada beberapa kendaraan dengan efisiensi energi yang tinggi di atas 6 km/kWh, hal ini menunjukkan adanya variasi teknologi efisiensi energi pada beberapa model kendaraan.

# %% [markdown]
# #Relationship

# %% [markdown]
# Aktivitas: Melakukan analisis korelasi antar variabel numerik
#
# Tujuan: Mengetahui bagaimana hubungan antara tahun model, daya kendaraan, waktu pengisian daya, dan efisiensi energi
#
# Visualisasi: Heatmap

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['Model year', 'Motor (kW)', 'Recharge time (h)', 'Energy Efficiency (km/kWh)']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Korelasi variabel numerik kendaraan listrik')
plt.show()

# %% [markdown]
# 1. Motor (kW) vs Recharge time (h) nilainya 0.63 positif dan cukup kuat. Artinya semakin besar daya kendaraan, semakin lama waktu chargingnya. karena semakin besar daya suatu kendaraan semakin besar baterainya dan baterai yang besar waktu pengisiannya akan lebih lama.
# 2. Motor (kW) vs Energy Efficiency (km/kWh) nilainya -0.46 negatif dan sedang. Artinya semakin besar daya motor, efisiensi energi cenderung menurun. daya yang besar sama dengan tenaga yang besar tapi konsumsi energi yang boros.
# 3. Recharge time (h) vs Energy Efficiecy (km/kWh) nilainya -0.47 negatif dan sedang. Artinya semakin lama waktu charging, efisiensi energi cenderung rendah. karena mobil dengan baterai besar butuh charging yang lama, tapi biasanya konsumsi energinya juga besar.
# 4. Model year vs Motor (kW) nilainya 0.24 positif dan lemah. Artinya semakin baru tahun kendaraan, daya kendaraan cenderung menurun. karena kemungkinan kendaraan listrik terbaru itu hanya dirancang untuk performa yang tinggi.
# 5. Model year vs Recharge time (h) nilainya 0.25 positif dan lemah. Artinya mobil baru waktu chargingnya lebih lama karena bisa jadi mobil baru memiliki baterai yang besar dan baterai yang besar itu waktu pengisiannya lama.
# 6. model year vs Energy Efficiency (km/kWh) nilainya -0,30 negatif dan lemah. Artinya semakin terbaru mobil efisiensinya sedikit menurun, karena kemungkinan mobil baru berfokus pada performa
